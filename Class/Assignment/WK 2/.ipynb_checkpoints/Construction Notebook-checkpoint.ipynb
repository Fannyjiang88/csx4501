# %%
import pandas

# %%
import construction_spending
spending = construction_spending.get_spending()

# %%
spending
# Out:
# [{'time': {'index': 1,
#    'month': 1,
#    'month name': 'Jan',
#    'period': 'Jan2002',
#    'year': 2002},
#   'annual': {'combined': {'amusement and recreation': 17866,
#     'commercial': 68254,
#     'communication': 18873,
#     'conservation and development': 3603,
#     'educational': 72357,
#     'health care': 25746,
#     'highway and street': 62723,
#     'lodging': 11862,
#     'manufacturing': 28318,
#     'nonresidential': 475704,
#     'office': 49140,
#     'power': 46050,
#     'public safety': 8468,
#     'religious': 8745,
#     'residential': 382979,
#     'sewage and waste disposal': 16392,
#     'total construction': 858654,
#     'transportation': 25547,
#     'water supply': 11760},
#    'private': {'amusement and recreation': 7822,
#     'commercial': 63972,
#     'communication': 18843,
#     'conservation and development': 0,
#     'educational': 13616,
#     'health care': 20888,
#     'highway and street': 0,
#     'lodging': 11669,
# ...

# %%
type(spending)
# Out:
# list

# %%
spending[0]['time']
# Out:
# {'index': 1,
#  'month': 1,
#  'month name': 'Jan',
#  'period': 'Jan2002',
#  'year': 2002}
